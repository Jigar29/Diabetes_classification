# %% [markdown]
# # Lumiata Data Science take-home assignment
#
# ## This notebook is structured in two parts
# ###   - The first portion is exploration of the data
# ###    - The second portion is where to put your code

# %% [markdown]
# # Explore the structure of the data first

# %% [markdown]
# ## Read in train.txt data

# %%
import json
from pprint import pprint

ls = []
with open('train.txt') as f:
    for line in f:
        ls.append(json.loads(line))

# %% [markdown]
# ## Show structure of each patient json
# ### (key_name, type_of_value_associated_to_key)

# %%
pprint(zip(ls[0].keys(), [type(ls[0][x]) for x in ls[0].keys()]))
# Out:
# [(u'is_male', <type 'bool'>),
#  (u'bday', <type 'unicode'>),
#  (u'patient_id', <type 'unicode'>),
#  (u'observations', <type 'dict'>),
#  (u'tag_dm2', <type 'unicode'>),
#  (u'resources', <type 'dict'>),
#  (u'split', <type 'unicode'>)]

# %% [markdown]
# ## Display patient json

# %%
pprint(ls[0])
# Out:
# {u'bday': u'1959-10-10',
#  u'is_male': False,
#  u'observations': {u'2014-05-21': [{u'code': u'loinc_24111-7',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_6356-0',
#                                     u'interpretation': None,
#                                     u'value': None}],
#                    u'2014-10-30': [{u'code': u'loinc_20405-7',
#                                     u'interpretation': u'L',
#                                     u'value': u'0.0'},
#                                    {u'code': u'loinc_21000-5',
#                                     u'interpretation': u'N',
#                                     u'value': u'13.0'},
#                                    {u'code': u'loinc_2514-8',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_25428-4',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_26444-0',
#                                     u'interpretation': u'N',
#                                     u'value': u'1.0'},
#                                    {u'code': u'loinc_26449-9',
#                                     u'interpretation': u'H',
#                                     u'value': u'5.0'},
#                                    {u'code': u'loinc_26474-7',
#                                     u'interpretation': u'N',
#                                     u'value': u'32.0'},
#                                    {u'code': u'loinc_26484-6',
#                                     u'interpretation': u'H',
#                                     u'value': u'9.0'},
#                                    {u'code': u'loinc_28539-5',
#                                     u'interpretation': u'N',
#                                     u'value': u'31.0'},
#                                    {u'code': u'loinc_30451-9',
#                                     u'interpretation': None,
#                                     u'value': u'51.0'},
#                                    {u'code': u'loinc_32167-9',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_32623-1',
#                                     u'interpretation': u'N',
#                                     u'value': u'9.0'},
#                                    {u'code': u'loinc_32776-7',
#                                     u'interpretation': u'N',
#                                     u'value': None},
#                                    {u'code': u'loinc_33825-1',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_4544-3',
#                                     u'interpretation': u'L',
#                                     u'value': u'34.0'},
#                                    {u'code': u'loinc_49754-5',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5770-3',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5778-6',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5794-3',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5799-2',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5802-4',
#                                     u'interpretation': None,
#                                     u'value': None},
#                                    {u'code': u'loinc_5803-2',
#                                     u'interpretation': None,
#                                     u'value': u'6.0'},
#                                    {u'code': u'loinc_5804-0',
#                                     u'interpretation': u'N',
#                                     u'value': None},
#                                    {u'code': u'loinc_5811-5',
#                                     u'interpretation': None,
#                                     u'value': u'1.0'},
#                                    {u'code': u'loinc_6690-2',
#                                     u'interpretation': u'N',
#                                     u'value': u'5.0'},
#                                    {u'code': u'loinc_718-7',
#                                     u'interpretation': u'L',
#                                     u'value': u'11.0'},
#                                    {u'code': u'loinc_777-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'220.0'},
#                                    {u'code': u'loinc_786-4',
#                                     u'interpretation': u'N',
#                                     u'value': u'33.0'},
#                                    {u'code': u'loinc_787-2',
#                                     u'interpretation': u'N',
#                                     u'value': u'91.0'},
#                                    {u'code': u'loinc_789-8',
#                                     u'interpretation': u'L',
#                                     u'value': u'3.0'}],
#                    u'2014-11-13': [{u'code': u'loinc_13457-7',
#                                     u'interpretation': u'N',
#                                     u'value': u'82.0'},
#                                    {u'code': u'loinc_1742-6',
#                                     u'interpretation': u'N',
#                                     u'value': u'21.0'},
#                                    {u'code': u'loinc_1751-7',
#                                     u'interpretation': u'L',
#                                     u'value': u'3.0'},
#                                    {u'code': u'loinc_1759-0',
#                                     u'interpretation': u'N',
#                                     u'value': u'1.0'},
#                                    {u'code': u'loinc_17861-6',
#                                     u'interpretation': u'N',
#                                     u'value': u'9.0'},
#                                    {u'code': u'loinc_1920-8',
#                                     u'interpretation': u'N',
#                                     u'value': u'18.0'},
#                                    {u'code': u'loinc_1975-2',
#                                     u'interpretation': u'L',
#                                     u'value': u'0.0'},
#                                    {u'code': u'loinc_1989-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'43.0'},
#                                    {u'code': u'loinc_2028-9',
#                                     u'interpretation': u'N',
#                                     u'value': u'29.0'},
#                                    {u'code': u'loinc_2075-0',
#                                     u'interpretation': u'N',
#                                     u'value': u'105.0'},
#                                    {u'code': u'loinc_2085-9',
#                                     u'interpretation': u'N',
#                                     u'value': u'61.0'},
#                                    {u'code': u'loinc_2093-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'156.0'},
#                                    {u'code': u'loinc_2160-0',
#                                     u'interpretation': u'L',
#                                     u'value': u'0.0'},
#                                    {u'code': u'loinc_2276-4',
#                                     u'interpretation': u'N',
#                                     u'value': u'24.0'},
#                                    {u'code': u'loinc_2345-7',
#                                     u'interpretation': u'N',
#                                     u'value': u'72.0'},
#                                    {u'code': u'loinc_2498-4',
#                                     u'interpretation': u'N',
#                                     u'value': u'65.0'},
#                                    {u'code': u'loinc_2500-7',
#                                     u'interpretation': u'N',
#                                     u'value': u'318.0'},
#                                    {u'code': u'loinc_2571-8',
#                                     u'interpretation': u'N',
#                                     u'value': u'66.0'},
#                                    {u'code': u'loinc_2823-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'4.0'},
#                                    {u'code': u'loinc_2885-2',
#                                     u'interpretation': u'N',
#                                     u'value': u'7.0'},
#                                    {u'code': u'loinc_2951-2',
#                                     u'interpretation': u'N',
#                                     u'value': u'141.0'},
#                                    {u'code': u'loinc_3016-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'1.0'},
#                                    {u'code': u'loinc_3094-0',
#                                     u'interpretation': u'N',
#                                     u'value': u'14.0'},
#                                    {u'code': u'loinc_33037-3',
#                                     u'interpretation': u'N',
#                                     u'value': u'7.0'},
#                                    {u'code': u'loinc_33914-3',
#                                     u'interpretation': None,
#                                     u'value': u'79.0'},
#                                    {u'code': u'loinc_44734-2',
#                                     u'interpretation': u'N',
#                                     u'value': u'17.0'},
#                                    {u'code': u'loinc_6768-6',
#                                     u'interpretation': u'N',
#                                     u'value': u'89.0'},
#                                    {u'code': u'loinc_9830-1',
#                                     u'interpretation': u'L',
#                                     u'value': u'2.0'}]},
#  u'patient_id': u'pat_0',
#  u'resources': {u'2014-01-13': [],
#                 u'2014-02-18': [],
#                 u'2014-03-21': [],
#                 u'2014-04-30': [],
#                 u'2014-05-21': [u'cpt_99213',
#                                 u'icd9_V85.23',
#                                 u'cpt_87210',
#                                 u'icd9_789.03',
#                                 u'cpt_87591',
#                                 u'cpt_87491',
#                                 u'icd9_616.10'],
#                 u'2014-06-05': [],
#                 u'2014-07-02': [u'cpt_99213', u'icd9_789.03', u'icd9_278.02'],
#                 u'2014-07-10': [u'cpt_72195', u'icd9_789.09'],
#                 u'2014-07-30': [],
#                 u'2014-08-06': [u'cpt_73510', u'icd9_789.03', u'cpt_99213'],
#                 u'2014-08-20': [u'icd9_564.00',
#                                 u'cpt_99213',
#                                 u'cpt_74000',
#                                 u'icd9_V85.1',
#                                 u'icd9_789.00'],
#                 u'2014-08-27': [],
#                 u'2014-09-06': [u'cpt_76856',
#                                 u'icd9_789.03',
#                                 u'icd9_625.9',
#                                 u'cpt_76830',
#                                 u'cpt_73721',
#                                 u'icd9_719.05'],
#                 u'2014-09-17': [u'icd9_V76.12', u'cpt_77057'],
#                 u'2014-09-20': [u'icd9_727.9', u'cpt_99213'],
#                 u'2014-09-30': [],
#                 u'2014-10-01': [u'cpt_97140',
#                                 u'icd9_719.45',
#                                 u'cpt_97110',
#                                 u'cpt_97001'],
#                 u'2014-10-07': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#                 u'2014-10-08': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#                 u'2014-10-14': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#                 u'2014-10-15': [u'icd9_719.45', u'cpt_97110'],
#                 u'2014-10-30': [u'icd9_780.79',
#                                 u'icd9_V72.31',
#                                 u'cpt_97110',
#                                 u'cpt_81003',
#                                 u'icd9_V49.81',
#                                 u'cpt_81001',
#                                 u'cpt_85025',
#                                 u'icd9_719.45',
#                                 u'cpt_77080',
#                                 u'icd9_599.72'],
#                 u'2014-11-13': [u'cpt_83540',
#                                 u'cpt_83550',
#                                 u'cpt_80053',
#                                 u'cpt_82728',
#                                 u'icd9_V72.31',
#                                 u'cpt_82306',
#                                 u'cpt_77080',
#                                 u'cpt_84443',
#                                 u'icd9_733.90',
#                                 u'cpt_80061'],
#                 u'2014-12-02': [],
#                 u'2014-12-23': [u'cpt_73610', u'icd9_719.47', u'cpt_99213'],
#                 u'2014-12-30': [],
#                 u'2015-01-20': [u'icd9_715.97',
#                                 u'icd9_796.2',
#                                 u'cpt_73590',
#                                 u'icd9_719.47',
#                                 u'cpt_99213',
#                                 u'cpt_L1902'],
#                 u'2015-01-21': [],
#                 u'2015-01-28': [],
#                 u'2015-02-24': [],
#                 u'2015-02-26': [],
#                 u'2015-03-22': [],
#                 u'2015-04-08': [],
#                 u'2015-04-19': [],
#                 u'2015-05-16': [],
#                 u'2015-06-11': [],
#                 u'2015-06-16': [],
#                 u'2015-07-07': [u'icd9_733.99',
#                                 u'icd9_729.5',
#                                 u'cpt_73630',
#                                 u'cpt_99213',
#                                 u'icd9_703.0'],
#                 u'2015-07-15': [],
#                 u'2015-08-13': [],
#                 u'2015-08-14': [],
#                 u'2015-09-12': [],
#                 u'2015-09-18': [u'cpt_99213',
#                                 u'icd9_V85.22',
#                                 u'icd9_278.02',
#                                 u'icd9_700'],
#                 u'2015-09-19': [],
#                 u'2015-10-02': [u'icd9_V76.12', u'cpt_77057'],
#                 u'2015-10-14': [],
#                 u'2015-10-30': [],
#                 u'2015-11-05': [u'cpt_73620',
#                                 u'cpt_99213',
#                                 u'icd10_L84',
#                                 u'cpt_11055'],
#                 u'2015-11-11': [],
#                 u'2015-12-11': [],
#                 u'2016-01-10': [],
#                 u'2016-01-14': [],
#                 u'2016-01-20': [u'icd10_L57.0',
#                                 u'cpt_99213',
#                                 u'icd10_L84',
#                                 u'cpt_17000'],
#                 u'2016-01-21': [],
#                 u'2016-02-11': [],
#                 u'2016-03-10': [],
#                 u'2016-03-14': [],
#                 u'2016-04-07': [],
#                 u'2016-04-13': [u'icd10_J40', u'cpt_87804', u'cpt_99213'],
#                 u'2016-04-17': [u'icd10_R30.0', u'cpt_99213'],
#                 u'2016-05-06': [],
#                 u'2016-06-08': [],
#                 u'2016-07-06': [],
#                 u'2016-07-13': [],
#                 u'2016-08-04': [],
#                 u'2016-08-10': [],
#                 u'2016-09-01': [],
#                 u'2016-09-06': [],
#                 u'2016-10-01': [],
#                 u'2016-10-29': [],
#                 u'2016-11-26': [],
#                 u'2016-12-14': [],
#                 u'2016-12-24': [],
#                 u'2017-01-07': [],
#                 u'2017-01-21': [],
#                 u'2017-02-21': [],
#                 u'2017-03-26': [],
#                 u'2017-04-07': [u'cpt_92133', u'icd10_H40.003', u'cpt_92083'],
#                 u'2017-04-28': [],
#                 u'2017-05-11': [u'icd10_F41.1', u'cpt_99213'],
#                 u'2017-06-10': [],
#                 u'2017-06-23': [u'icd10_Z12.31'],
#                 u'2017-07-02': [],
#                 u'2017-08-07': [],
#                 u'2017-10-31': []},
#  u'split': u'train',
#  u'tag_dm2': u''}

# %% [markdown]
# ## Show 'resources' key

# %%
pprint(ls[0]['resources'])
# Out:
# {u'2014-01-13': [],
#  u'2014-02-18': [],
#  u'2014-03-21': [],
#  u'2014-04-30': [],
#  u'2014-05-21': [u'cpt_99213',
#                  u'icd9_V85.23',
#                  u'cpt_87210',
#                  u'icd9_789.03',
#                  u'cpt_87591',
#                  u'cpt_87491',
#                  u'icd9_616.10'],
#  u'2014-06-05': [],
#  u'2014-07-02': [u'cpt_99213', u'icd9_789.03', u'icd9_278.02'],
#  u'2014-07-10': [u'cpt_72195', u'icd9_789.09'],
#  u'2014-07-30': [],
#  u'2014-08-06': [u'cpt_73510', u'icd9_789.03', u'cpt_99213'],
#  u'2014-08-20': [u'icd9_564.00',
#                  u'cpt_99213',
#                  u'cpt_74000',
#                  u'icd9_V85.1',
#                  u'icd9_789.00'],
#  u'2014-08-27': [],
#  u'2014-09-06': [u'cpt_76856',
#                  u'icd9_789.03',
#                  u'icd9_625.9',
#                  u'cpt_76830',
#                  u'cpt_73721',
#                  u'icd9_719.05'],
#  u'2014-09-17': [u'icd9_V76.12', u'cpt_77057'],
#  u'2014-09-20': [u'icd9_727.9', u'cpt_99213'],
#  u'2014-09-30': [],
#  u'2014-10-01': [u'cpt_97140', u'icd9_719.45', u'cpt_97110', u'cpt_97001'],
#  u'2014-10-07': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#  u'2014-10-08': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#  u'2014-10-14': [u'cpt_97140', u'icd9_719.45', u'cpt_97110'],
#  u'2014-10-15': [u'icd9_719.45', u'cpt_97110'],
#  u'2014-10-30': [u'icd9_780.79',
#                  u'icd9_V72.31',
#                  u'cpt_97110',
#                  u'cpt_81003',
#                  u'icd9_V49.81',
#                  u'cpt_81001',
#                  u'cpt_85025',
#                  u'icd9_719.45',
#                  u'cpt_77080',
#                  u'icd9_599.72'],
#  u'2014-11-13': [u'cpt_83540',
#                  u'cpt_83550',
#                  u'cpt_80053',
#                  u'cpt_82728',
#                  u'icd9_V72.31',
#                  u'cpt_82306',
#                  u'cpt_77080',
#                  u'cpt_84443',
#                  u'icd9_733.90',
#                  u'cpt_80061'],
#  u'2014-12-02': [],
#  u'2014-12-23': [u'cpt_73610', u'icd9_719.47', u'cpt_99213'],
#  u'2014-12-30': [],
#  u'2015-01-20': [u'icd9_715.97',
#                  u'icd9_796.2',
#                  u'cpt_73590',
#                  u'icd9_719.47',
#                  u'cpt_99213',
#                  u'cpt_L1902'],
#  u'2015-01-21': [],
#  u'2015-01-28': [],
#  u'2015-02-24': [],
#  u'2015-02-26': [],
#  u'2015-03-22': [],
#  u'2015-04-08': [],
#  u'2015-04-19': [],
#  u'2015-05-16': [],
#  u'2015-06-11': [],
#  u'2015-06-16': [],
#  u'2015-07-07': [u'icd9_733.99',
#                  u'icd9_729.5',
#                  u'cpt_73630',
#                  u'cpt_99213',
#                  u'icd9_703.0'],
#  u'2015-07-15': [],
#  u'2015-08-13': [],
#  u'2015-08-14': [],
#  u'2015-09-12': [],
#  u'2015-09-18': [u'cpt_99213', u'icd9_V85.22', u'icd9_278.02', u'icd9_700'],
#  u'2015-09-19': [],
#  u'2015-10-02': [u'icd9_V76.12', u'cpt_77057'],
#  u'2015-10-14': [],
#  u'2015-10-30': [],
#  u'2015-11-05': [u'cpt_73620', u'cpt_99213', u'icd10_L84', u'cpt_11055'],
#  u'2015-11-11': [],
#  u'2015-12-11': [],
#  u'2016-01-10': [],
#  u'2016-01-14': [],
#  u'2016-01-20': [u'icd10_L57.0', u'cpt_99213', u'icd10_L84', u'cpt_17000'],
#  u'2016-01-21': [],
#  u'2016-02-11': [],
#  u'2016-03-10': [],
#  u'2016-03-14': [],
#  u'2016-04-07': [],
#  u'2016-04-13': [u'icd10_J40', u'cpt_87804', u'cpt_99213'],
#  u'2016-04-17': [u'icd10_R30.0', u'cpt_99213'],
#  u'2016-05-06': [],
#  u'2016-06-08': [],
#  u'2016-07-06': [],
#  u'2016-07-13': [],
#  u'2016-08-04': [],
#  u'2016-08-10': [],
#  u'2016-09-01': [],
#  u'2016-09-06': [],
#  u'2016-10-01': [],
#  u'2016-10-29': [],
#  u'2016-11-26': [],
#  u'2016-12-14': [],
#  u'2016-12-24': [],
#  u'2017-01-07': [],
#  u'2017-01-21': [],
#  u'2017-02-21': [],
#  u'2017-03-26': [],
#  u'2017-04-07': [u'cpt_92133', u'icd10_H40.003', u'cpt_92083'],
#  u'2017-04-28': [],
#  u'2017-05-11': [u'icd10_F41.1', u'cpt_99213'],
#  u'2017-06-10': [],
#  u'2017-06-23': [u'icd10_Z12.31'],
#  u'2017-07-02': [],
#  u'2017-08-07': [],
#  u'2017-10-31': []}

# %% [markdown]
# ## Show 'observations' key

# %%
pprint(ls[0]['observations'])
# Out:
# {u'2014-05-21': [{u'code': u'loinc_24111-7',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_6356-0',
#                   u'interpretation': None,
#                   u'value': None}],
#  u'2014-10-30': [{u'code': u'loinc_20405-7',
#                   u'interpretation': u'L',
#                   u'value': u'0.0'},
#                  {u'code': u'loinc_21000-5',
#                   u'interpretation': u'N',
#                   u'value': u'13.0'},
#                  {u'code': u'loinc_2514-8',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_25428-4',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_26444-0',
#                   u'interpretation': u'N',
#                   u'value': u'1.0'},
#                  {u'code': u'loinc_26449-9',
#                   u'interpretation': u'H',
#                   u'value': u'5.0'},
#                  {u'code': u'loinc_26474-7',
#                   u'interpretation': u'N',
#                   u'value': u'32.0'},
#                  {u'code': u'loinc_26484-6',
#                   u'interpretation': u'H',
#                   u'value': u'9.0'},
#                  {u'code': u'loinc_28539-5',
#                   u'interpretation': u'N',
#                   u'value': u'31.0'},
#                  {u'code': u'loinc_30451-9',
#                   u'interpretation': None,
#                   u'value': u'51.0'},
#                  {u'code': u'loinc_32167-9',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_32623-1',
#                   u'interpretation': u'N',
#                   u'value': u'9.0'},
#                  {u'code': u'loinc_32776-7',
#                   u'interpretation': u'N',
#                   u'value': None},
#                  {u'code': u'loinc_33825-1',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_4544-3',
#                   u'interpretation': u'L',
#                   u'value': u'34.0'},
#                  {u'code': u'loinc_49754-5',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5770-3',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5778-6',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5794-3',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5799-2',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5802-4',
#                   u'interpretation': None,
#                   u'value': None},
#                  {u'code': u'loinc_5803-2',
#                   u'interpretation': None,
#                   u'value': u'6.0'},
#                  {u'code': u'loinc_5804-0',
#                   u'interpretation': u'N',
#                   u'value': None},
#                  {u'code': u'loinc_5811-5',
#                   u'interpretation': None,
#                   u'value': u'1.0'},
#                  {u'code': u'loinc_6690-2',
#                   u'interpretation': u'N',
#                   u'value': u'5.0'},
#                  {u'code': u'loinc_718-7',
#                   u'interpretation': u'L',
#                   u'value': u'11.0'},
#                  {u'code': u'loinc_777-3',
#                   u'interpretation': u'N',
#                   u'value': u'220.0'},
#                  {u'code': u'loinc_786-4',
#                   u'interpretation': u'N',
#                   u'value': u'33.0'},
#                  {u'code': u'loinc_787-2',
#                   u'interpretation': u'N',
#                   u'value': u'91.0'},
#                  {u'code': u'loinc_789-8',
#                   u'interpretation': u'L',
#                   u'value': u'3.0'}],
#  u'2014-11-13': [{u'code': u'loinc_13457-7',
#                   u'interpretation': u'N',
#                   u'value': u'82.0'},
#                  {u'code': u'loinc_1742-6',
#                   u'interpretation': u'N',
#                   u'value': u'21.0'},
#                  {u'code': u'loinc_1751-7',
#                   u'interpretation': u'L',
#                   u'value': u'3.0'},
#                  {u'code': u'loinc_1759-0',
#                   u'interpretation': u'N',
#                   u'value': u'1.0'},
#                  {u'code': u'loinc_17861-6',
#                   u'interpretation': u'N',
#                   u'value': u'9.0'},
#                  {u'code': u'loinc_1920-8',
#                   u'interpretation': u'N',
#                   u'value': u'18.0'},
#                  {u'code': u'loinc_1975-2',
#                   u'interpretation': u'L',
#                   u'value': u'0.0'},
#                  {u'code': u'loinc_1989-3',
#                   u'interpretation': u'N',
#                   u'value': u'43.0'},
#                  {u'code': u'loinc_2028-9',
#                   u'interpretation': u'N',
#                   u'value': u'29.0'},
#                  {u'code': u'loinc_2075-0',
#                   u'interpretation': u'N',
#                   u'value': u'105.0'},
#                  {u'code': u'loinc_2085-9',
#                   u'interpretation': u'N',
#                   u'value': u'61.0'},
#                  {u'code': u'loinc_2093-3',
#                   u'interpretation': u'N',
#                   u'value': u'156.0'},
#                  {u'code': u'loinc_2160-0',
#                   u'interpretation': u'L',
#                   u'value': u'0.0'},
#                  {u'code': u'loinc_2276-4',
#                   u'interpretation': u'N',
#                   u'value': u'24.0'},
#                  {u'code': u'loinc_2345-7',
#                   u'interpretation': u'N',
#                   u'value': u'72.0'},
#                  {u'code': u'loinc_2498-4',
#                   u'interpretation': u'N',
#                   u'value': u'65.0'},
#                  {u'code': u'loinc_2500-7',
#                   u'interpretation': u'N',
#                   u'value': u'318.0'},
#                  {u'code': u'loinc_2571-8',
#                   u'interpretation': u'N',
#                   u'value': u'66.0'},
#                  {u'code': u'loinc_2823-3',
#                   u'interpretation': u'N',
#                   u'value': u'4.0'},
#                  {u'code': u'loinc_2885-2',
#                   u'interpretation': u'N',
#                   u'value': u'7.0'},
#                  {u'code': u'loinc_2951-2',
#                   u'interpretation': u'N',
#                   u'value': u'141.0'},
#                  {u'code': u'loinc_3016-3',
#                   u'interpretation': u'N',
#                   u'value': u'1.0'},
#                  {u'code': u'loinc_3094-0',
#                   u'interpretation': u'N',
#                   u'value': u'14.0'},
#                  {u'code': u'loinc_33037-3',
#                   u'interpretation': u'N',
#                   u'value': u'7.0'},
#                  {u'code': u'loinc_33914-3',
#                   u'interpretation': None,
#                   u'value': u'79.0'},
#                  {u'code': u'loinc_44734-2',
#                   u'interpretation': u'N',
#                   u'value': u'17.0'},
#                  {u'code': u'loinc_6768-6',
#                   u'interpretation': u'N',
#                   u'value': u'89.0'},
#                  {u'code': u'loinc_9830-1',
#                   u'interpretation': u'L',
#                   u'value': u'2.0'}]}

# %% [markdown]
# # Fill your code below this line

# %% [markdown]
# ## 1. Experimental setup/design

# %% [markdown]
# ## 2. Feature design/feature selection

# %% [markdown]
# ## 3. Model selection/tuning

# %% [markdown]
# ## 4. Model performance evaluation (i.e how well it does along the metrics above)

# %% [markdown]
# ## 5. A short write-up (2-3 paragraph) of your approach. Be sure to include the following:
# ### - Top 5 most important features for predicting diabetes - have a rationale for why you think these are most important
# ### - Briefly describe the model you used for training
# ### - Explain how you optimized your model, and what performance metrics you optimized for
# ### -How did you prevent overfitting?
